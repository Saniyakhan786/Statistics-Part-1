# %%
from scipy import stats

# %%
#stats.norm.cdf(x,loc=mean,scale=std.dev)          
stats.norm.cdf(680,loc=711,scale=29)                 #calculation for normal distribution
# Out:
# 0.14254260383881612

# %%
#Normal Distribution Calculation

# %%
import pandas as pd
import numpy as np

# %%
#Importing both the files

# %%
beml_df=pd.read_csv("C:/Users/saniyakhan/Downloads/BEML.csv")

# %%
beml_df
# Out:
#             Date     Open     High      Low     Last    Close  \
# 0     2010-01-04  1121.00  1151.00  1121.00  1134.00  1135.60
# 1     2010-01-05  1146.80  1149.00  1128.75  1135.00  1134.60
# 2     2010-01-06  1140.00  1164.25  1130.05  1137.00  1139.60
# 3     2010-01-07  1142.00  1159.40  1119.20  1141.00  1144.15
# 4     2010-01-08  1156.00  1172.00  1140.00  1141.20  1144.05
# ...          ...      ...      ...      ...      ...      ...
# 1734  2016-12-26   965.00   965.05   935.00   950.10   950.25
# 1735  2016-12-27   960.70   989.00   952.35   974.00   975.70
# 1736  2016-12-28   980.75   985.00   970.15   977.00   974.40
# 1737  2016-12-29   977.10   997.95   974.55   985.15   986.05
# 1738  2016-12-30   986.00  1006.95   985.90  1004.00  1000.60
#
#       Total Trade Quantity  Turnover (Lacs)
# 0                 101651.0          1157.18
# 1                  59504.0           676.47
# 2                 128908.0          1482.84
# 3                 117871.0          1352.98
# 4                 170063.0          1971.42
# ...                    ...              ...
# 1734              398696.0          3783.63
# 1735              808561.0          7885.14
# 1736              367041.0          3592.49
# 1737              555233.0          5489.14
# 1738              460675.0          4606.48
#
# [1739 rows x 8 columns]

# %%
glaxo_df=pd.read_csv("C:/Users/saniyakhan/Downloads/GLAXO.csv")

# %%
glaxo_df
# Out:
#             Date     Open     High      Low    Last    Close  \
# 0     2010-01-04  1613.00  1629.10  1602.00  1629.0  1625.65
# 1     2010-01-05  1639.95  1639.95  1611.05  1620.0  1616.80
# 2     2010-01-06  1618.00  1644.00  1617.00  1639.0  1638.50
# 3     2010-01-07  1645.00  1654.00  1636.00  1648.0  1648.70
# 4     2010-01-08  1650.00  1650.00  1626.55  1640.0  1639.80
# ...          ...      ...      ...      ...     ...      ...
# 1734  2016-12-26  2703.00  2740.00  2677.00  2715.0  2723.50
# 1735  2016-12-27  2722.95  2725.00  2683.00  2692.0  2701.75
# 1736  2016-12-28  2701.75  2718.00  2690.00  2698.0  2702.15
# 1737  2016-12-29  2702.05  2739.00  2691.95  2710.0  2727.90
# 1738  2016-12-30  2730.00  2740.45  2705.00  2730.0  2729.80
#
#       Total Trade Quantity  Turnover (Lacs)
# 0                   9365.0           151.74
# 1                  38148.0           622.58
# 2                  36519.0           595.09
# 3                  12809.0           211.00
# 4                  28035.0           459.11
# ...                    ...              ...
# 1734                3953.0           107.15
# 1735               10600.0           286.10
# 1736                6050.0           163.44
# 1737                7649.0           207.87
# 1738                6513.0           177.65
#
# [1739 rows x 8 columns]

# %%
#Get the closing prices of both the stocks along with the date       
#Gain= Closing Price - Closing Price / Closing Price

# %%
beml_df=beml_df[['Close','Date']]
beml_df
# Out:
#         Close        Date
# 0     1135.60  2010-01-04
# 1     1134.60  2010-01-05
# 2     1139.60  2010-01-06
# 3     1144.15  2010-01-07
# 4     1144.05  2010-01-08
# ...       ...         ...
# 1734   950.25  2016-12-26
# 1735   975.70  2016-12-27
# 1736   974.40  2016-12-28
# 1737   986.05  2016-12-29
# 1738  1000.60  2016-12-30
#
# [1739 rows x 2 columns]

# %%
glaxo_df=glaxo_df[['Close','Date']]
glaxo_df
# Out:
#         Close        Date
# 0     1625.65  2010-01-04
# 1     1616.80  2010-01-05
# 2     1638.50  2010-01-06
# 3     1648.70  2010-01-07
# 4     1639.80  2010-01-08
# ...       ...         ...
# 1734  2723.50  2016-12-26
# 1735  2701.75  2016-12-27
# 1736  2702.15  2016-12-28
# 1737  2727.90  2016-12-29
# 1738  2729.80  2016-12-30
#
# [1739 rows x 2 columns]

# %%
#The dataframe have a date column,so we can create a DatetimeIndex index from this column Date. It will ensure that the rows are
#sorted by time in ascending order
#Set the date as index for the dateframe to calculate gains

# %%
beml_df=beml_df.set_index(pd.DatetimeIndex(beml_df['Date']))
beml_df
# Out:
#               Close        Date
# Date
# 2010-01-04  1135.60  2010-01-04
# 2010-01-05  1134.60  2010-01-05
# 2010-01-06  1139.60  2010-01-06
# 2010-01-07  1144.15  2010-01-07
# 2010-01-08  1144.05  2010-01-08
# ...             ...         ...
# 2016-12-26   950.25  2016-12-26
# 2016-12-27   975.70  2016-12-27
# 2016-12-28   974.40  2016-12-28
# 2016-12-29   986.05  2016-12-29
# 2016-12-30  1000.60  2016-12-30
#
# [1739 rows x 2 columns]

# %%
glaxo_df=glaxo_df.set_index(pd.DatetimeIndex(beml_df['Date']))
glaxo_df
# Out:
#               Close        Date
# Date
# 2010-01-04  1625.65  2010-01-04
# 2010-01-05  1616.80  2010-01-05
# 2010-01-06  1638.50  2010-01-06
# 2010-01-07  1648.70  2010-01-07
# 2010-01-08  1639.80  2010-01-08
# ...             ...         ...
# 2016-12-26  2723.50  2016-12-26
# 2016-12-27  2701.75  2016-12-27
# 2016-12-28  2702.15  2016-12-28
# 2016-12-29  2727.90  2016-12-29
# 2016-12-30  2729.80  2016-12-30
#
# [1739 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sn
# %matplotlib inline

# %%
#Plot the price against time for Glaxo Stock

# %%
plt.plot(glaxo_df.Close);
plt.xlabel('Time');
plt.ylabel('Close Price');

# %%
plt.plot(beml_df.Close);
plt.xlabel('Time');
plt.ylabel('Close Price');

# %%
#Create the gain column using pct_change() method
#Gain=Closing price(t)-Closing Price(t-1)/Closing Price(t-1)

# %%
beml_df['Gain']=beml_df.Close.pct_change(periods=1)     #here pct_change is the formula & periods is the daily basis calculation
beml_df
# Out:
#               Close        Date      Gain
# Date
# 2010-01-04  1135.60  2010-01-04       NaN
# 2010-01-05  1134.60  2010-01-05 -0.000881
# 2010-01-06  1139.60  2010-01-06  0.004407
# 2010-01-07  1144.15  2010-01-07  0.003993
# 2010-01-08  1144.05  2010-01-08 -0.000087
# ...             ...         ...       ...
# 2016-12-26   950.25  2016-12-26 -0.021924
# 2016-12-27   975.70  2016-12-27  0.026782
# 2016-12-28   974.40  2016-12-28 -0.001332
# 2016-12-29   986.05  2016-12-29  0.011956
# 2016-12-30  1000.60  2016-12-30  0.014756
#
# [1739 rows x 3 columns]

# %%
glaxo_df['Gain']=glaxo_df.Close.pct_change(periods=1)     #here pct_change is the formula & periods is the daily basis calculation
glaxo_df
# Out:
#               Close        Date      Gain
# Date
# 2010-01-04  1625.65  2010-01-04       NaN
# 2010-01-05  1616.80  2010-01-05 -0.005444
# 2010-01-06  1638.50  2010-01-06  0.013422
# 2010-01-07  1648.70  2010-01-07  0.006225
# 2010-01-08  1639.80  2010-01-08 -0.005398
# ...             ...         ...       ...
# 2016-12-26  2723.50  2016-12-26 -0.001283
# 2016-12-27  2701.75  2016-12-27 -0.007986
# 2016-12-28  2702.15  2016-12-28  0.000148
# 2016-12-29  2727.90  2016-12-29  0.009529
# 2016-12-30  2729.80  2016-12-30  0.000697
#
# [1739 rows x 3 columns]

# %%
#Drop the first row since its NaN

# %%
beml_df=beml_df.dropna()         #drop the missing values it will drop the wole row
beml_df
# Out:
#               Close        Date      Gain
# Date
# 2010-01-05  1134.60  2010-01-05 -0.000881
# 2010-01-06  1139.60  2010-01-06  0.004407
# 2010-01-07  1144.15  2010-01-07  0.003993
# 2010-01-08  1144.05  2010-01-08 -0.000087
# 2010-01-11  1137.00  2010-01-11 -0.006162
# ...             ...         ...       ...
# 2016-12-26   950.25  2016-12-26 -0.021924
# 2016-12-27   975.70  2016-12-27  0.026782
# 2016-12-28   974.40  2016-12-28 -0.001332
# 2016-12-29   986.05  2016-12-29  0.011956
# 2016-12-30  1000.60  2016-12-30  0.014756
#
# [1738 rows x 3 columns]

# %%
glaxo_df=glaxo_df.dropna()         #drop the missing values it will drop the wole row
glaxo_df
# Out:
#               Close        Date      Gain
# Date
# 2010-01-05  1616.80  2010-01-05 -0.005444
# 2010-01-06  1638.50  2010-01-06  0.013422
# 2010-01-07  1648.70  2010-01-07  0.006225
# 2010-01-08  1639.80  2010-01-08 -0.005398
# 2010-01-11  1629.45  2010-01-11 -0.006312
# ...             ...         ...       ...
# 2016-12-26  2723.50  2016-12-26 -0.001283
# 2016-12-27  2701.75  2016-12-27 -0.007986
# 2016-12-28  2702.15  2016-12-28  0.000148
# 2016-12-29  2727.90  2016-12-29  0.009529
# 2016-12-30  2729.80  2016-12-30  0.000697
#
# [1738 rows x 3 columns]

# %%
#Plot the Gains

# %%
plt.figure(figsize=(8,6));
plt.plot(beml_df.index,beml_df.Gain);
plt.xlabel('Time');
plt.ylabel('Gain');

# %%
plt.figure(figsize=(8,6));
plt.plot(glaxo_df.index,glaxo_df.Gain);
plt.xlabel('Time');
plt.ylabel('Gain');

# %%
sn.distplot(beml_df.Gain,label='Beml');
plt.xlabel('Gain');
plt.ylabel('Density');
plt.legend;

# %%
#To find mean and standard deviation

# %%
print('Mean:',round(beml_df.Gain.mean(),4))
# Out:
# Mean: 0.0003

# %%
print('Standard Deviation:',round(beml_df.Gain.std(),4))
# Out:
# Standard Deviation: 0.0264

# %%
print('Mean:',round(glaxo_df.Gain.mean(),4))
# Out:
# Mean: 0.0004

# %%
print('Standard Deviation:',round(glaxo_df.Gain.std(),4))
# Out:
# Standard Deviation: 0.0134

# %%
from scipy import stats

# %%
#Probability of making 2% loss or higher in Glaxo file

# %%
stats.norm.cdf(-0.02,
loc=glaxo_df.Gain.mean(),
scale=glaxo_df.Gain.std())
# Out:
# 0.06352488667177397

# %%
#Probability of making 2% high or higher in Glaxo file

# %%
1-stats.norm.cdf(-0.02,
loc=glaxo_df.Gain.mean(),
scale=glaxo_df.Gain.std())
# Out:
# 0.9364751133282261
